# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('DSBDALExam DataSets/Iris/Iris.csv', header=None)
column_names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
df.columns = column_names
df['Id'] = df.index

# %%
df.index.name = 'Id'
df['Id'] = df['Id'].astype(int)

# %%
df.head(50)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  Id
# Id
# 0             5.1           3.5            1.4           0.2  Iris-setosa   1
# 1             4.9           3.0            1.4           0.2  Iris-setosa   2
# 2             4.7           3.2            1.3           0.2  Iris-setosa   3
# 3             4.6           3.1            1.5           0.2  Iris-setosa   4
# 4             5.0           3.6            1.4           0.2  Iris-setosa   5
# 5             5.4           3.9            1.7           0.4  Iris-setosa   6
# 6             4.6           3.4            1.4           0.3  Iris-setosa   7
# 7             5.0           3.4            1.5           0.2  Iris-setosa   8
# 8             4.4           2.9            1.4           0.2  Iris-setosa   9
# 9             4.9           3.1            1.5           0.1  Iris-setosa  10
# 10            5.4           3.7            1.5           0.2  Iris-setosa  11
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Id
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.054000       3.758667      1.198667   75.500000
# std         0.828066      0.433594       1.764420      0.763161   43.445368
# min         4.300000      2.000000       1.000000      0.100000    1.000000
# 25%         5.100000      2.800000       1.600000      0.300000   38.250000
# 50%         5.800000      3.000000       4.350000      1.300000   75.500000
# 75%         6.400000      3.300000       5.100000      1.800000  112.750000
# max         7.900000      4.400000       6.900000      2.500000  150.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
#  5   Id             150 non-null    int32
# dtypes: float64(4), int32(1), object(1)
# memory usage: 6.6+ KB

# %%
df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# Id               0
# dtype: int64

# %%
np.random.seed(42)
mask = np.random.rand(*df.shape) < 0.05
df[mask] = np.nan

# %%
df.isna().sum()
# Out:
# SepalLengthCm     8
# SepalWidthCm      2
# PetalLengthCm     9
# PetalWidthCm      4
# Species          14
# Id               11
# dtype: int64

# %%
df.fillna(df.mode().iloc[0], inplace=True)

# %%
df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# Id               0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
subset1 = df[df['Species'] == 'Iris-setosa']

# %%
subset1.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species   Id
# Id
# 0             5.1           3.5            1.4           0.2  Iris-setosa  1.0
# 2             4.7           3.2            1.3           0.2  Iris-setosa  3.0
# 3             4.6           3.1            1.5           0.2  Iris-setosa  4.0
# 4             5.0           3.6            1.4           0.2  Iris-setosa  1.0
# 5             5.4           3.9            1.7           0.4  Iris-setosa  6.0

# %%
subset2 = df[df['Species'] == 'Iris-virginica']

# %%
subset2.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 100            6.3           3.3            6.0           2.5  Iris-virginica
# 102            7.1           3.0            5.9           2.1  Iris-virginica
# 103            6.3           2.9            5.6           1.8  Iris-virginica
# 105            7.6           3.0            6.6           2.1  Iris-virginica
# 107            7.3           2.9            6.3           1.8  Iris-virginica
#
#         Id
# Id
# 100  101.0
# 102  103.0
# 103  104.0
# 105  106.0
# 107  108.0

# %%
subset3 = df[df['Species'] == 'Iris-versicolor']

# %%
subset3.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species  \
# Id
# 1             4.9           3.0            1.4           0.2  Iris-versicolor
# 9             4.9           3.1            1.5           0.1  Iris-versicolor
# 16            5.4           3.9            1.4           0.4  Iris-versicolor
# 34            4.9           3.0            1.5           0.1  Iris-versicolor
# 40            5.0           3.5            1.3           0.3  Iris-versicolor
#
#       Id
# Id
# 1    2.0
# 9   10.0
# 16  17.0
# 34  35.0
# 40  41.0

# %%
subset1.shape
# Out:
# (45, 6)

# %%
subset2.shape
# Out:
# (44, 6)

# %%
subset3.shape
# Out:
# (61, 6)

# %%
merged_data = pd.concat([subset1, subset2])

# %%
merged_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 143            6.8           3.2            5.9           2.3  Iris-virginica
# 144            6.7           3.3            5.7           2.5  Iris-virginica
# 146            6.3           2.5            1.4           1.9  Iris-virginica
# 147            5.0           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
#
#         Id
# Id
# ...

# %%
merged_data.shape
# Out:
# (89, 6)

# %%
sorted_data = df.sort_values(by='PetalLengthCm', ascending=True)

# %%
sorted_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 22             4.6           3.6            1.0           0.2     Iris-setosa
# 13             4.3           3.0            1.1           0.1     Iris-setosa
# 35             5.0           3.2            1.2           0.2     Iris-setosa
# 14             5.8           4.0            1.2           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 131            7.9           3.8            6.4           2.0  Iris-virginica
# 105            7.6           3.0            6.6           2.1  Iris-virginica
# 117            7.7           3.8            6.7           2.2  Iris-virginica
# 122            7.7           2.8            6.7           2.0  Iris-virginica
# 118            7.7           2.6            6.9           2.3  Iris-virginica
#
#         Id
# Id
# ...

# %%
transposed_data = df.T

# %%
transposed_data
# Out:
# Id                     0                1            2            3    \
# SepalLengthCm          5.1              4.9          4.7          4.6
# SepalWidthCm           3.5              3.0          3.2          3.1
# PetalLengthCm          1.4              1.4          1.3          1.5
# PetalWidthCm           0.2              0.2          0.2          0.2
# Species        Iris-setosa  Iris-versicolor  Iris-setosa  Iris-setosa
# Id                     1.0              2.0          3.0          4.0
#
# Id                     4            5            6            7    \
# SepalLengthCm          5.0          5.4          4.6          5.0
# SepalWidthCm           3.6          3.9          3.4          3.4
# PetalLengthCm          1.4          1.7          1.4          1.5
# PetalWidthCm           0.2          0.4          0.3          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
# Id                     1.0          6.0          7.0          8.0
#
# ...

# %%
melted_data = pd.melt(df, id_vars=['Id','Species'], value_vars=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], var_name='Measurement', value_name='Value')

# %%
melted_data
# Out:
#         Id          Species    Measurement  Value
# 0      1.0      Iris-setosa  SepalLengthCm    5.1
# 1      2.0  Iris-versicolor  SepalLengthCm    4.9
# 2      3.0      Iris-setosa  SepalLengthCm    4.7
# 3      4.0      Iris-setosa  SepalLengthCm    4.6
# 4      1.0      Iris-setosa  SepalLengthCm    5.0
# ..     ...              ...            ...    ...
# 595  146.0  Iris-versicolor   PetalWidthCm    2.3
# 596  147.0   Iris-virginica   PetalWidthCm    1.9
# 597  148.0   Iris-virginica   PetalWidthCm    2.0
# 598  149.0   Iris-virginica   PetalWidthCm    2.3
# 599  150.0  Iris-versicolor   PetalWidthCm    1.8
#
# [600 rows x 4 columns]

# %%
casted_data = melted_data.pivot_table(index=['Id', 'Species'], columns='Measurement', values='Value').reset_index()

# %%
casted_data
# Out:
# Measurement     Id          Species  PetalLengthCm  PetalWidthCm  \
# 0              1.0      Iris-setosa       1.400000      0.200000
# 1              1.0  Iris-versicolor       3.655556      1.211111
# 2              1.0   Iris-virginica       5.600000      2.400000
# 3              2.0  Iris-versicolor       1.400000      0.200000
# 4              3.0      Iris-setosa       1.300000      0.200000
# ..             ...              ...            ...           ...
# 136          146.0  Iris-versicolor       5.200000      2.300000
# 137          147.0   Iris-virginica       1.400000      1.900000
# 138          148.0   Iris-virginica       5.200000      2.000000
# 139          149.0   Iris-virginica       5.400000      2.300000
# 140          150.0  Iris-versicolor       5.100000      1.800000
#
# Measurement  SepalLengthCm  SepalWidthCm
# 0                 5.050000      3.550000
# 1                 5.644444      2.688889
# 2                 6.300000      3.400000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(figsize=(10, 12))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df, hue='Species', diag_kind='hist')
plt.show()

# %%
sns.pairplot(df, hue='Species', diag_kind='kde')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=df, hue='Species')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['Species'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Iris Species')
plt.show()
