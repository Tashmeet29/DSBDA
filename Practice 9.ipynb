# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('dataset_Facebook.csv', delimiter=';')
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.index.name = 'Id'

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.isna().sum().sum()
# Out:
# 6

# %%
data['Paid'].fillna(data['Paid'].mean(), inplace=True)
data['like'].fillna(data['like'].mean(), inplace=True)
data['share'].fillna(data['share'].mean(), inplace=True)

# %%
data.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
subset1 = data[data["Type"] == "Photo"]
subset2 = data[data["Type"] == "Status"]
subset3 = data[data["Type"] == "Video"]
subset4 = data[data["Type"] == "Link"]

# %%
subset1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
subset3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# Id
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# ...

# %%
subset4
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
subset1.shape
# Out:
# (426, 19)

# %%
subset2.shape
# Out:
# (45, 19)

# %%
subset3.shape
# Out:
# (7, 19)

# %%
subset4.shape
# Out:
# (22, 19)

# %%
merged_data1 = pd.concat([subset1, subset3])

# %%
merged_data1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
# ...

# %%
merged_data2 = pd.concat([subset2, subset4])

# %%
merged_data2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# ..                ...     ...       ...         ...           ...        ...
# 470             91437    Link         1           2             3         13
# 477             86909    Link         1           1             6          4
# 481             86491    Link         1           1             4          4
# 485             86491    Link         1           1             2          2
# 492             85979    Link         1           1             5         11
#
# ...

# %%
merged_data = pd.concat([merged_data1, merged_data2])
merged_data
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 470             91437   Link         1           2             3         13
# 477             86909   Link         1           1             6          4
# 481             86491   Link         1           1             4          4
# 485             86491   Link         1           1             2          2
# 492             85979   Link         1           1             5         11
#
# ...

# %%
merged_data.shape
# Out:
# (500, 19)

# %%
sorted_data = data.sort_values(by='Page total likes', ascending=False)

# %%
sorted_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# Id
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
#transposed_data = data.T
#OR
transposed_data = data.transpose()

# %%
transposed_data
# Out:
# Id                                                     0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
melted_data = pd.melt(data, id_vars=['Page total likes'], value_vars=['comment', 'like', 'share', 'Total Interactions'], var_name='Metric', value_name='Value')

# %%
melted_data.index.name = 'Id'
melted_data
# Out:
#       Page total likes              Metric  Value
# Id
# 0               139441             comment    4.0
# 1               139441             comment    5.0
# 2               139441             comment    0.0
# 3               139441             comment   58.0
# 4               139441             comment   19.0
# ...                ...                 ...    ...
# 1995             85093  Total Interactions   84.0
# 1996             81370  Total Interactions   75.0
# 1997             81370  Total Interactions  115.0
# 1998             81370  Total Interactions  136.0
# 1999             81370  Total Interactions  119.0
#
# [2000 rows x 3 columns]

# %%
casted_data = melted_data.pivot_table(index=['Id','Page total likes'], columns='Metric', values='Value').reset_index()

# %%
casted_data
# Out:
# Metric    Id  Page total likes  Total Interactions  comment  like  share
# 0          0            139441                 NaN      4.0   NaN    NaN
# 1          1            139441                 NaN      5.0   NaN    NaN
# 2          2            139441                 NaN      0.0   NaN    NaN
# 3          3            139441                 NaN     58.0   NaN    NaN
# 4          4            139441                 NaN     19.0   NaN    NaN
# ...      ...               ...                 ...      ...   ...    ...
# 1995    1995             85093                84.0      NaN   NaN    NaN
# 1996    1996             81370                75.0      NaN   NaN    NaN
# 1997    1997             81370               115.0      NaN   NaN    NaN
# 1998    1998             81370               136.0      NaN   NaN    NaN
# 1999    1999             81370               119.0      NaN   NaN    NaN
#
# [2000 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.hist(figsize=(16, 12))
plt.tight_layout()
plt.show()

# %%
x_column = 'Lifetime Post Total Reach'
y_column = 'Total Interactions'

plt.figure(figsize=(10,6))
plt.scatter(data[x_column], data[y_column], alpha=0.5)
plt.title('Scatter Plot of Lifetime Post Total Reach vs Total Interactions')
plt.xlabel('Lifetime Post Total Reach')
plt.ylabel('Total Interactions')
plt.grid(True)
plt.show()
