# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_reviews(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

    # Introduce a delay to avoid being blocked
    time.sleep(2)

    # Send a request to the URL with headers
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extracting reviews
        reviews = []
        review_elements = soup.find_all('div', class_='a-section review aok-relative')

        for review_element in review_elements:
            review = {
                'customer_name': review_element.find('span', class_='a-profile-name').text.strip(),
                'rating': review_element.find('span', class_='a-icon-alt').text.split()[0],
                'review': review_element.find('span', class_='a-size-base review-text review-text-content').text.strip()
            }
            reviews.append(review)

        return reviews
    else:
        print(f"Failed to retrieve data. Status code: {response.status_code}")
        return None

if __name__ == "__main__":
    # Amazon URL for OnePlus product reviews
    amazon_url = 'https://www.amazon.in/Redmi-Startrail-Storage-MediaTek-Dimensity/product-reviews/B0CNX6WVG5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

    # Scrape and print the reviews
    scraped_reviews = scrape_reviews(amazon_url)

    if scraped_reviews:
        print("Number of Reviews:", len(scraped_reviews))
        for idx, review in enumerate(scraped_reviews, start=1):
            print(f"Review #{idx}:")
            print(f"Customer Name: {review['customer_name']}")
            print(f"Rating: {review['rating']}")
            print(f"Review: {review['review']}")
            print("\n" + "="*50 + "\n")
    else:
        print("No reviews were scraped.")
# Out:
# Number of Reviews: 10
# Review #1:
# Customer Name: Navneet Singh
# Rating: 5.0
# Review: Product is good as per its budget. It is a basic product which doesn’t lags and performs all basic requirements of a smartphone very well. However don’t expect very good gaming performance, its a bugdet phone after all.Camera quality is above average and justifies the price tag.
#
# ...
#
# Review #2:
# Customer Name: sourav b.
# Rating: 4.0
# Review: This is a very good product under this range of amount I will very happy to use the productsThe camera quality is not goodBut the 5g speed is very good working and this is a good 5g phone 7nder this budget.
#
# ...
#
# Review #3:
# Customer Name: Dr. Yashvinder
# Rating: 5.0
# Review: Battery back up is average..... but lock of the phone is awesome
#
# ...
#
# Review #4:
# Customer Name: Placeholder
# Rating: 1.0
# ...

# %%
import requests
import bs4

# %%
request1 = requests.get('https://www.flipkart.com/poco-x6-pro-5g-spectre-black-512-gb/p/itme39d84b843d40')

# %%
request1
# Out:
# <Response [200]>

# %%
request1.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
soup = bs4.BeautifulSoup(request1.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Fetching Reviews
reviews = soup.findAll('div', {'class': 'ZmyHeo'})
for review in reviews:
    print(review.get_text() + "\n\n")
# Out:
# Overall good phone 1- good sound quality 5/52- good display 5/53- decant camera 3/5 (not bad much better then average but don't expect like Samsung's and iPhones like) 4- good battery 5000mah 4/5 (quite good battery backup fast charging out of the box)5- good processor mdt dimensity 8300 ultra 5/5 ( gaming beast lag free on every game like bgmi/ cod/ mlbb/ Genshin Impact / coc idk other game i play only this 5games daily). [LPDDR 5x and ufsufs4 storage, game turbo mode, and Wild Boost 2...READ MORE
#
#
# GooD ProductREAD MORE
#
#
# This is a true flagship killerREAD MORE
#
#
# ...

# %%
# Average Overall Rating
ratings = soup.find('div', {'class':'ipqd2A'}).get_text();
print(ratings)
# Out:
# 4.3

# %%
# Individual Ratings
individual_ratings = soup.findAll('div', {'class': 'XQDdHH Ga3i8K'});
for indi_rating in individual_ratings:
    print(indi_rating.get_text() + "\n")
# Out:
# 5
#
# 5
#
# 5
#
# 5
#
# 5
#
# 4
#
# 4
#
# 5
#
# 5
#
# 5

# %%
# tags = soup.find('span', {'class': ''}).get_text();
# tags

# %%
customer_name = soup.findAll('p', {'class': '_2NsDsF AwS1CA'});
for cust_name in customer_name:
    print(cust_name.get_text() + "\n")
# Out:
# Prashant
#
# Kishan Singh
#
# Flipkart Customer
#
# SRINIVASA S
#
# Suman Paul
#
# Samata Maity
#
# Juel Ansari
#
# Shiv Balak
#
# Suresh G
#
# Sankar Panda

# %%
# Fetch Price of Product
price = soup.find('div', {'class': 'Nx9bqj CxhGGd'}).get_text();
print(price)
# Out:
# ₹25,999

# %%
questions = soup.find_all('div', {'class': 'wys2hv _43gOsC'});
for question in questions:
    print(question.get_text())
    answer = question.findNext('div', {'class': 'JxAXcP'}).get_text();
    print(answer + "\n\n")
# Out:
# Q:Is there any motherboard issue in poco phone any more ?
# A:No there is no problem in the motherboard of poco X6 pro.
#
#
# Q:Can poco F5 charger can be used for this one as both are 67W chargers?
# A:Yes
#
#
# Q:3.5 audio jack available
# A:No
#
#
# Q:Please confirm the Gorilla Glass Victus.
# A:No victims , just GG5
#
#
# Q:Can we use realme 18 Watt charger to charge this phone.
# A:Yes, you can. I wouldn't recommend it though. But why would you use 18w charger when you have original 67w charger that comes with the device.
#
#
# Q:Free fire ultra graphics play?????
# A:Yes very easily.
#
#
# Q:What is The camara function?
# A:Camera is low grade because it is not for camera fone it's a gaming phone.If compair the camera of xiaomi poco X2 then you can know how down grade poco X6 pro camera. If you want camera then go for
#
#
# Q:Bgmi accepted 90 fps in this phone.
# A:Yes smooth + 90fps.
#
#
# Q:Battery 100 % hai to kab drain hoge
# A:7 hours
#
#
# ...

# %%
specifications = soup.find_all('td', {'class': '+fFi1w'});
for specification in specifications:
    print(specification.get_text())
    answer = specification.findNext('td', {'class': 'Izz52n'}).get_text();
    print(answer+ "\n\n")
# Out:
# In The Box
# Handset, 67W Charger, USB Type-C Cable, Sim Eject Tool, Protective Case, Quick Start Guide, Warranty Card
#
#
# Model Number
# MZB0FW2IN
#
#
# Model Name
# X6 Pro 5G
#
#
# Color
# Spectre Black
#
#
# Browse Type
# Smartphones
#
#
# SIM Type
# Dual Sim
#
#
# Hybrid Sim Slot
# No
#
#
# Touchscreen
# Yes
#
#
# OTG Compatible
# Yes
#
#
# Quick Charging
# Yes
#
#
# SAR Value
# SAR Limit: 1.6 W/kg, Head: 0.903 W/kg, Body: 0.860 W/kg
#
#
# Display Size
# 16.94 cm (6.67 inch)
#
#
# Resolution
# 2712 x 1220 Pixels
#
#
# GPU
# Arm Mali-G615
#
#
# Display Type
# 120Hz 1.5K AMOLED Display
#
#
# Other Display Features
# Dolby Vision, Contrast: 5,000,000:1, 68 Billion+ Colors, Corning Gorilla Glass Protected, 1920Hz PWM Dimming, 1800 Nits Peak Brightness, 2160Hz Instantaneous Touch Sampling Rate, Screen-to-Body Ratio: 94.27%
#
#
# Operating System
# Android 14
#
#
# Processor Brand
# Mediatek
#
#
# Processor Type
# Dimensity D8300 Ultra
#
#
# Processor Core
# Octa Core
#
#
# ...

# %%
import requests
import bs4

# %%
# Sending request to fetch data from the URL
request1 = requests.get('https://www.flipkart.com/poco-x6-pro-5g-spectre-black-512-gb/p/itme39d84b843d40')

# %%
# Fetching content of the page
request1
# Out:
# <Response [200]>

# %%
# Creating BeautifulSoup object to parse the HTML content
soup = bs4.BeautifulSoup(request1.text)

# Fetching Reviews
reviews = soup.findAll('div', {'class': 'ZmyHeo'})
for review in reviews:
    print(review.get_text() + "\n\n")

# Average Overall Rating
ratings = soup.find('div', {'class':'ipqd2A'}).get_text();
print(ratings)

# Individual Ratings
individual_ratings = soup.findAll('div', {'class': 'XQDdHH Ga3i8K'});
for indi_rating in individual_ratings:
    print(indi_rating.get_text() + "\n")

# Customer Names
customer_name = soup.findAll('p', {'class': 'z9E0IG'});
for cust_name in customer_name:
    print(cust_name.get_text() + "\n")

# Fetch Price of Product
price = soup.find('div', {'class': 'Nx9bqj CxhGGd'}).get_text();
print(price)

# Frequently Asked Questions
questions = soup.find_all('div', {'class': 'wys2hv _43gOsC'});
for question in questions:
    print(question.get_text())
    answer = question.findNext('div', {'class': 'JxAXcP'}).get_text();
    print(answer + "\n\n")

# Specifications
specifications = soup.find_all('td', {'class': '+fFi1w'});
for specification in specifications:
    print(specification.get_text())
    answer = specification.findNext('td', {'class': 'Izz52n'}).get_text();
    print(answer+ "\n\n")
# Out:
# Overall good phone 1- good sound quality 5/52- good display 5/53- decant camera 3/5 (not bad much better then average but don't expect like Samsung's and iPhones like) 4- good battery 5000mah 4/5 (quite good battery backup fast charging out of the box)5- good processor mdt dimensity 8300 ultra 5/5 ( gaming beast lag free on every game like bgmi/ cod/ mlbb/ Genshin Impact / coc idk other game i play only this 5games daily). [LPDDR 5x and ufsufs4 storage, game turbo mode, and Wild Boost 2...READ MORE
#
#
# GooD ProductREAD MORE
#
#
# This is a true flagship killerREAD MORE
#
#
# ...

# %%
import requests
import bs4

# %%
# Sending request to fetch data from the URL
request2 = requests.get('https://www.flipkart.com/vivo-t2-pro-5g-dune-gold-256-gb/p/itm1230688cdef18?pid=MOBGT4RZUPKD8HDK&lid=LSTMOBGT4RZUPKD8HDK4QMUBF&marketplace=FLIPKART&cmpid=content_mobile_8965229628_gmc')

# %%
request2
# Out:
# <Response [200]>

# %%
soup = bs4.BeautifulSoup(request2.text)
# Extracting reviews
reviews = []
for review_element in soup.find_all('div', class_='RcXBOT'):
    customer_name_elem = review_element.find('p', class_='_2NsDsF AwS1CA')
    rating_elem = review_element.find('div', class_='XQDdHH Ga3i8K')
    review_text_elem = review_element.find('div', class_='ZmyHeo')

    if customer_name_elem and rating_elem and review_text_elem:
        review = {
            'customer_name': customer_name_elem.text.strip(),
            'rating': rating_elem.text.strip()[0],
            'review_text': review_text_elem.text.strip()
        }
        reviews.append(review)
    else:
        print("Some elements not found for a review.")

if __name__ == "__main__":
    print("Number of Reviews:", len(reviews))
    for idx, review in enumerate(reviews, start=1):
        print(f"Review #{idx}:")
        print(f"Customer Name: {review['customer_name']}")
        print(f"Rating: {review['rating']}")
        print(f"Review: {review['review_text']}")
        print("\n" + "="*50 + "\n")
else:
    print("No reviews were scraped.")
# Out:
# Some elements not found for a review.
# Number of Reviews: 10
# Review #1:
# Customer Name: Prashant
# Rating: 5
# Review: Over all good phone 📱🔥, go through itREAD MORE
#
# ...
#
# Review #2:
# Customer Name: Kishan Singh
# Rating: 5
# Review: If you using 5000 mah battery smartphone before so some time you feel battery is small but with 66 wat fast charging its absolute fine other wise it is Totally Beast.Mic Drop.READ MORE
#
# ...
#
# Review #3:
# Customer Name: Flipkart Customer
# Rating: 4
# Review: All good at the price ..but need one ultra wide cameraREAD MORE
#
# ...
#
# Review #4:
# Customer Name: SRINIVASA S
# Rating: 5
# Review: The design and display of the phone is very good.camer is super for day and night photos.READ MORE
#
# ...
#
# Review #5:
# Customer Name: Suman Paul
# Rating: 5
# Review: Phone quality awesome.. design..camera.. best 😘😘👌👌👌👌READ MORE
#
# ...
#
# Review #6:
# Customer Name: Samata Maity
# Rating: 5
# Review: Nice camera 🤳....READ MORE
#
# ...
#
# Review #7:
# ...
